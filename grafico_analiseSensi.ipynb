# %%
import pandas as pd
import matplotlib.pyplot as plt
import matplotlib.ticker as ticker

# %%
db0 = pd.read_excel('sensitivity.xlsx')          # skiprows = range(0, 1)) eu posso pular a primeira linha do meu DB que é default do RSWAT
db0
# Out:
#       Parameter     t_stat  absolute_t_stat        p_value
# 0       CN2.mgt  45.172202        45.172202  3.940161e-214
# 1      ESCO.hru  28.463518        28.463518  1.168502e-120
# 2   SOL_AWC.sol -26.846194        26.846194  3.903621e-111
# 3     CH_N2.rte -16.733890        16.733890   1.728773e-53
# 4   GW_DELAY.gw -14.944461        14.944461   2.771712e-44
# 5      EPCO.hru  -9.686873         9.686873   5.783900e-21
# 6     SOL_K.sol   7.079153         7.079153   3.397070e-12
# 7   RCHRG_DP.gw  -6.763121         6.763121   2.758555e-11
# 8   GW_REVAP.gw  -1.488313         1.488313   1.370980e-01
# 9   ALPHA_BF.gw   1.406657         1.406657   1.599523e-01
# 10     ESCO.bsn  -1.336632         1.336632   1.817569e-01
# 11    CH_K2.rte   1.102720         1.102720   2.705103e-01
# 12   SURLAG.bsn   0.895787         0.895787   3.706603e-01
# 13     GWQMN.gw  -0.533048         0.533048   5.941618e-01
# 14   REVAPMN.gw   0.515901         0.515901   6.060788e-01

# %%
fig, (ax1,ax2) = plt.subplots(1,2,figsize=(9,7), sharey=True, layout='tight')

a = ax1.barh(db['Parameter'], db['p_value'], color='c', ec='k')
b = ax2.barh(db['Parameter'], db['t_stat'], align='center', color='g', ec='k')   #funcao barh, deixa as barras deitadas

ax1.bar_label(a,label_type='edge', fmt='%.1f', padding=2)   #numeros nos graficos
ax2.bar_label(b,label_type='edge', fmt='%.1f', padding=2)
ax1.axvline(0.05, ls='--', color='r')   #coloca no plot 1 uma linha para separar parametros com p_value < 0.05
ax2.axvline(0, ls='-', color='black', linewidth=0.4)    #coloca uma linha no plot 2, com certo grau de grossura

ax1.set_xlim(0,0.7)
ax2.set_xlim(-60,60)    #Coloca o eixo x os range que eu queria para aquele eixo

ax2.tick_params(left=False)   #remove as linhas dos tickes no eixo y no plot 2
# ax2.set(yticklabels=[])   #remove os tickes dos eixos y, porem, remove dos 2 plot

ax1.set_ylabel('Parameters', fontsize=16)   #exibe no plot 1, no eixo y o texto
ax2.set_xlabel('t-stat')    #exibe o s_stat no plot 2, no eixo x
ax1.set_xlabel('p-value')   #exibe o p_value no plot 1, no eixo x

# DEIXAR EIXOS VISIVEIS OU NAO
ax1.spines['top'].set_visible(False)
ax1.spines['right'].set_visible(False)

ax2.spines['left'].set_visible(False)
ax2.spines['top'].set_visible(False)
ax2.spines['right'].set_visible(False)



ax1.text(0, 1.05, 'a)', transform=ax1.transAxes, fontsize=16, fontweight='bold', va='top', ha='left')   #Letra A no gráfico
ax2.text(0, 1.05, 'b)', transform=ax2.transAxes, fontsize=16, fontweight='bold', va='top', ha='left')   #Letra B no gráfico
plt.show()
fig.savefig('/Users/lucaslima/Library/CloudStorage/GoogleDrive-lucas8888.santi@gmail.com/O meu disco/RibeiraoPinhal/analise_sensitivity.png', facecolor='w', bbox_inches='tight', dpi=600)
# nome para colocar na dissertacao, "Sensitivity of flow parameters for the first(A), second(B), third(C) and fourth(D) test".

# %% [markdown]
# # Mapa do Estado

# %% [markdown]
# ## Pacotes

# %%
import pandas as pd
import matplotlib.pyplot as plt
import matplotlib.ticker as ticker

# %% [markdown]
# ## Lendo arquivo

# %%
db = pd.read_excel(r'C:\Users\Lucas\Documents\lucas\calibracao\estado\estado1\analises\analise_sens\par_sensi.xlsx', skiprows=range(0,1))           # skiprows = range(0, 1)) eu posso pular a primeira linha do meu DB que é default do RSWAT
db
# Out:
#       Parameter     t_stat  absolute_t_stat        p_value
# 0       CN2.mgt  50.104744        50.104744  4.853005e-273
# 1      ESCO.hru  45.217450        45.217450  1.869584e-242
# 2     CH_N2.rte -26.285838        26.285838  8.755287e-116
# 3   SOL_AWC.sol -26.201805        26.201805  3.209911e-115
# 4   GW_DELAY.gw -23.357545        23.357545   2.361444e-96
# 5   RCHRG_DP.gw -11.620944        11.620944   2.408230e-29
# 6      EPCO.hru -11.353074        11.353074   3.705040e-28
# 7     SOL_K.sol   4.958474         4.958474   8.364554e-07
# 8   ALPHA_BF.gw   2.160100         2.160100   3.100582e-02
# 9      ESCO.bsn  -1.333070         1.333070   1.828173e-01
# 10  GW_REVAP.gw  -0.823123         0.823123   4.106373e-01
# 11     GWQMN.gw  -0.715690         0.715690   4.743527e-01
# 12    CH_K2.rte   0.592616         0.592616   5.535745e-01
# 13   SURLAG.bsn  -0.575025         0.575025   5.654061e-01
# 14   REVAPMN.gw  -0.559723         0.559723   5.757958e-01

# %% [markdown]
# ## Plotando o gráfico

# %%
fig, (ax1,ax2) = plt.subplots(1,2,figsize=(9,7), sharey=True, layout='tight')

a = ax1.barh(db['Parameter'], db['p_value'], color='c', ec='k')
b = ax2.barh(db['Parameter'], db['t_stat'], align='center', color='g', ec='k')   #funcao barh, deixa as barras deitadas

ax1.bar_label(a,label_type='edge', fmt='%.1f', padding=2)   #numeros nos graficos
ax2.bar_label(b,label_type='edge', fmt='%.1f', padding=2)
ax1.axvline(0.05, ls='--', color='r')   #coloca no plot 1 uma linha para separar parametros com p_value < 0.05
ax2.axvline(0, ls='-', color='black', linewidth=0.4)    #coloca uma linha no plot 2, com certo grau de grossura

ax1.set_xlim(0,0.7)
ax2.set_xlim(-60,60)    #Coloca o eixo x os range que eu queria para aquele eixo

ax2.tick_params(left=False)   #remove as linhas dos tickes no eixo y no plot 2
# ax2.set(yticklabels=[])   #remove os tickes dos eixos y, porem, remove dos 2 plot

ax1.set_ylabel('Parameters', fontsize=16)   #exibe no plot 1, no eixo y o texto
ax2.set_xlabel('t-stat')    #exibe o s_stat no plot 2, no eixo x
ax1.set_xlabel('p-value')   #exibe o p_value no plot 1, no eixo x

# DEIXAR EIXOS VISIVEIS OU NAO
ax1.spines['top'].set_visible(False)
ax1.spines['right'].set_visible(False)

ax2.spines['left'].set_visible(False)
ax2.spines['top'].set_visible(False)
ax2.spines['right'].set_visible(False)



ax1.text(0, 1.05, 'a)', transform=ax1.transAxes, fontsize=16, fontweight='bold', va='top', ha='left')   #Letra A no gráfico
ax2.text(0, 1.05, 'b)', transform=ax2.transAxes, fontsize=16, fontweight='bold', va='top', ha='left')   #Letra B no gráfico
plt.show()
fig.savefig(r'G:\Meu Drive\RibeiraoPinhal\imagens\estado\analise_sensitivity_estado.png', facecolor='w', bbox_inches='tight', dpi=600)
# nome para colocar na dissertacao, "Sensitivity of flow parameters for the first(A), second(B), third(C) and fourth(D) test".

# %% [markdown]
# # Modelo da Quadrícula

# %% [markdown]
# ## pacotes

# %%
import pandas as pd
import matplotlib.pyplot as plt
import matplotlib.ticker as ticker

# %% [markdown]
# ## Lendo arquivo

# %%
db1 = pd.read_excel(r"G:\Meu Drive\RibeiraoPinhal\r_swat\time_simulation\quadricula\analise_sensibilidade\par_sens.xlsx", skiprows=range(0,1))           # skiprows = range(0, 1)) eu posso pular a primeira linha do meu DB que é default do RSWAT
db1
# Out:
#       Parameter     t_stat  absolute_t_stat        p_value
# 0       CN2.mgt  60.940529        60.940529   0.000000e+00
# 1      ESCO.bsn  -0.257854         0.257854   7.965738e-01
# 2   SOL_AWC.sol -11.989830        11.989830   5.168869e-31
# 3     SOL_K.sol   3.100963         3.100963   1.983835e-03
# 4    SURLAG.bsn  -0.666807         0.666807   5.050516e-01
# 5   ALPHA_BF.gw  -0.948988         0.948988   3.428597e-01
# 6   GW_DELAY.gw -13.056266        13.056266   4.788995e-36
# 7      GWQMN.gw   0.386176         0.386176   6.994495e-01
# 8   GW_REVAP.gw  -0.217220         0.217220   8.280822e-01
# 9   RCHRG_DP.gw  -5.426766         5.426766   7.226686e-08
# 10   REVAPMN.gw   0.045112         0.045112   9.640276e-01
# 11     ESCO.hru  33.980187        33.980187  4.606190e-168
# 12     EPCO.hru  -8.252276         8.252276   4.956363e-16
# 13    CH_K2.rte   2.595159         2.595159   9.595453e-03
# 14    CH_N2.rte -19.239555        19.239555   2.868752e-70

# %% [markdown]
# ## Plotando o gráfico

# %%
fig, (ax1,ax2) = plt.subplots(1,2,figsize=(9,7), sharey=True, layout='tight')

a = ax1.barh(db1['Parameter'], db1['p_value'], color='c', ec='k')
b = ax2.barh(db1['Parameter'], db1['t_stat'], align='center', color='g', ec='k')   #funcao barh, deixa as barras deitadas

ax1.bar_label(a,label_type='edge', fmt='%.1f', padding=2)   #numeros nos graficos
ax2.bar_label(b,label_type='edge', fmt='%.1f', padding=2)
ax1.axvline(0.05, ls='--', color='r')   #coloca no plot 1 uma linha para separar parametros com p_value < 0.05
ax2.axvline(0, ls='-', color='black', linewidth=0.4)    #coloca uma linha no plot 2, com certo grau de grossura

ax1.set_xlim(0,1.1)
ax2.set_xlim(-70,70)    #Coloca o eixo x os range que eu queria para aquele eixo

ax2.tick_params(left=False)   #remove as linhas dos tickes no eixo y no plot 2
# ax2.set(yticklabels=[])   #remove os tickes dos eixos y, porem, remove dos 2 plot

ax1.set_ylabel('Parameters', fontsize=16)   #exibe no plot 1, no eixo y o texto
ax2.set_xlabel('t-stat')    #exibe o s_stat no plot 2, no eixo x
ax1.set_xlabel('p-value')   #exibe o p_value no plot 1, no eixo x

# DEIXAR EIXOS VISIVEIS OU NAO
ax1.spines['top'].set_visible(False)
ax1.spines['right'].set_visible(False)

ax2.spines['left'].set_visible(False)
ax2.spines['top'].set_visible(False)
ax2.spines['right'].set_visible(False)



ax1.text(0, 1.05, 'a)', transform=ax1.transAxes, fontsize=16, fontweight='bold', va='top', ha='left')   #Letra A no gráfico
ax2.text(0, 1.05, 'b)', transform=ax2.transAxes, fontsize=16, fontweight='bold', va='top', ha='left')   #Letra B no gráfico
plt.show()
fig.savefig(r'G:\Meu Drive\RibeiraoPinhal\imagens\quadricula\analise_sensitivity_estado.png', facecolor='w', bbox_inches='tight', dpi=600)
# nome para colocar na dissertacao, "Sensitivity of flow parameters for the first(A), second(B), third(C) and fourth(D) test".

# %% [markdown]
# # Modelo da bacia

# %% [markdown]
# ## Pacotes

# %%
import pandas as pd
import matplotlib.pyplot as plt
import matplotlib.ticker as ticker

# %% [markdown]
# ## Lendo arquivos

# %%
db2 = pd.read_excel(r'G:\Meu Drive\RibeiraoPinhal\r_swat\time_simulation\bacia\analise_sensibilidade\parameter_sensiveis.xlsx', skiprows=range(0,1))           # skiprows = range(0, 1)) eu posso pular a primeira linha do meu DB que é default do RSWAT
db2
# Out:
#       Parameter     t_stat  absolute_t_stat        p_value
# 0       CN2.mgt  66.564769        66.564769   0.000000e+00
# 1      ESCO.hru  37.684103        37.684103  4.416024e-193
# 2     CH_N2.rte -18.509067        18.509067   7.343407e-66
# 3   GW_DELAY.gw -17.120838        17.120838   1.024543e-57
# 4   SOL_AWC.sol -11.675346        11.675346   1.374329e-29
# 5   RCHRG_DP.gw  -8.794294         8.794294   6.336696e-18
# 6      EPCO.hru  -7.476894         7.476894   1.681103e-13
# 7     SOL_K.sol   2.466053         2.466053   1.383073e-02
# 8     CH_K2.rte  -1.549682         1.549682   1.215394e-01
# 9    SURLAG.bsn   1.000335         1.000335   3.173944e-01
# 10     ESCO.bsn   0.666898         0.666898   5.049935e-01
# 11  GW_REVAP.gw   0.571760         0.571760   5.676150e-01
# 12   REVAPMN.gw  -0.417936         0.417936   6.760851e-01
# 13  ALPHA_BF.gw   0.163450         0.163450   8.701976e-01
# 14     GWQMN.gw   0.024335         0.024335   9.805906e-01

# %% [markdown]
# ## Plotando o gráfico

# %%
fig, (ax1,ax2) = plt.subplots(1,2,figsize=(9,7), sharey=True, layout='tight')

a = ax1.barh(db2['Parameter'], db2['p_value'], color='c', ec='k')
b = ax2.barh(db2['Parameter'], db2['t_stat'], align='center', color='g', ec='k')   #funcao barh, deixa as barras deitadas

ax1.bar_label(a,label_type='edge', fmt='%.1f', padding=2)   #numeros nos graficos
ax2.bar_label(b,label_type='edge', fmt='%.1f', padding=2)
ax1.axvline(0.05, ls='--', color='r')   #coloca no plot 1 uma linha para separar parametros com p_value < 0.05
ax2.axvline(0, ls='-', color='black', linewidth=0.4)    #coloca uma linha no plot 2, com certo grau de grossura

ax1.set_xlim(0,1.1)
ax2.set_xlim(-70,70)    #Coloca o eixo x os range que eu queria para aquele eixo

ax2.tick_params(left=False)   #remove as linhas dos tickes no eixo y no plot 2
# ax2.set(yticklabels=[])   #remove os tickes dos eixos y, porem, remove dos 2 plot

ax1.set_ylabel('Parameters', fontsize=16)   #exibe no plot 1, no eixo y o texto
ax2.set_xlabel('t-stat')    #exibe o s_stat no plot 2, no eixo x
ax1.set_xlabel('p-value')   #exibe o p_value no plot 1, no eixo x

# DEIXAR EIXOS VISIVEIS OU NAO
ax1.spines['top'].set_visible(False)
ax1.spines['right'].set_visible(False)

ax2.spines['left'].set_visible(False)
ax2.spines['top'].set_visible(False)
ax2.spines['right'].set_visible(False)



ax1.text(0, 1.05, 'a)', transform=ax1.transAxes, fontsize=16, fontweight='bold', va='top', ha='left')   #Letra A no gráfico
ax2.text(0, 1.05, 'b)', transform=ax2.transAxes, fontsize=16, fontweight='bold', va='top', ha='left')   #Letra B no gráfico
plt.show()
fig.savefig(r'G:\Meu Drive\RibeiraoPinhal\imagens\bacia\analise_sensitivity_estado.png', facecolor='w', bbox_inches='tight', dpi=600)
# nome para colocar na dissertacao, "Sensitivity of flow parameters for the first(A), second(B), third(C) and fourth(D) test".
